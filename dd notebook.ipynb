# %%
import random
import scipy.stats as ss
import math

# %%
#Add senior council?

BOARD = ['Danika', 'Hannah', 'Amy', 'Chris',
        'Kathy', 'Carol', 'Alvin', 'Will', 
        'David', 'Tex', 'Kalos', 'Glen',
        'Shwe', 'Vick', 'Margo', 'Audrey G', 
        'Eric', 'Janice', 'Daniel', 'Cody', 
        'Christy', 'Steph', 'Audrey K', 'Christina',
        'Ricky', 'Serena', 'Sophia']
GROUP_SIZE = 4
boardSize = len(BOARD)
EVEN_OUT_INDEX = 24
# list of dicts
history = [{'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0},
          {'Danika':0, 'Hannah':0, 'Amy':0, 'Chris':0,
        'Kathy':0, 'Carol':0, 'Alvin':0, 'Will':0, 
        'David':0, 'Tex':0, 'Kalos':0, 'Glen':0,
        'Shwe':0, 'Vick':0, 'Margo':0, 'Audrey G':0, 
        'Eric':0, 'Janice':0, 'Daniel':0, 'Cody':0, 
        'Christy':0, 'Steph':0, 'Audrey K':0, 'Christina':0,
        'Ricky':0, 'Serena':0, 'Sophia':0}]
history[BOARD.index('Chris')]['Christina'] += 2
history[BOARD.index('Christina')]['Chris'] += 2

# %%
def initialize():
    # random numbers for everyone
    randomNums = [random.random() for _ in range(boardSize)]
    
    # converts random floats to rank ordering
    ranks = ss.rankdata(randomNums)
    
    # matches a random number 1-30 to board members
    board = zip(BOARD, ranks)
    
    # sort members by random number (1-4 is a group, 2-8...)
    board = sorted(board, key = lambda p: p[1])
    
    
    # check if redo is necessary (no members meet twice)
    for i in range(0, boardSize, 4):
        # go through first three members in the group
        for j in range(i, i+3):
            # check each member's history
            for k in range(i, i+3):
                if j != k and history[BOARD.index(board[j][0])][board[k][0]] > 1:
                    return('redo')
        # go through fourth member's history in groups of 4
        if i != EVEN_OUT_INDEX:
            for k in range(i, i+3):
                 if history[BOARD.index(board[i+3][0])][board[k][0]] > 1:
                    return('redo')    
      

    # add to member history and print out groups
    for i in range(0, boardSize, 4):
        for j in range(i, i+3):
            for k in range(i, i+3):
                if j != k:
                    history[BOARD.index(board[j][0])][board[k][0]] += 1

        # store group
        tmp = [board[i][0], board[i+1][0], board[i+2][0]]
        
        # deal with fourth member
        if i != EVEN_OUT_INDEX:
            for k in range(i, i+3):
                 history[BOARD.index(board[i+3][0])][board[k][0]] += 1
            tmp += [board[i+3][0]]
        
        # print gruops
        (print(', '.join(tmp)))
        

if __name__ == "__main__":
    for i in range(1,17):
        print("Week", i,": ")
        while initialize() == 'redo':
            pass
# Out:
# Week 1 :
# Chris, Amy, Daniel, Shwe
# Vick, Kalos, Cody, Christy
# Hannah, Sophia, Audrey G, Serena
# David, Alvin, Eric, Janice
# Glen, Steph, Audrey K, Carol
# Ricky, Danika, Margo, Will
# Christina, Tex, Kathy
# Week 2 :
# Kathy, Amy, Janice, Ricky
# Eric, Hannah, Serena, Vick
# Audrey K, Glen, Daniel, Cody
# Shwe, Margo, Alvin, Chris
# Christy, Carol, Christina, Danika
# Steph, Kalos, Audrey G, Sophia
# David, Will, Tex
# Week 3 :
# Chris, Audrey K, Margo, Sophia
# Eric, David, Audrey G, Shwe
# Glen, Tex, Will, Steph
# Alvin, Vick, Cody, Serena
# Kalos, Carol, Janice, Ricky
# Hannah, Danika, Amy, Kathy
# Christina, Christy, Daniel
# Week 4 :
# Ricky, Vick, Daniel, Audrey G
# Chris, Danika, Audrey K, Christy
# Carol, Shwe, Hannah, Tex
# Eric, Steph, Janice, Glen
# Amy, Kalos, Sophia, Cody
# Will, David, Margo, Kathy
# Serena, Christina, Alvin
# Week 5 :
# Christina, Alvin, Kathy, Glen
# Christy, Audrey K, Daniel, David
# Hannah, Amy, Vick, Sophia
# Chris, Ricky, Eric, Kalos
# ...

# %%
history
# Out:
# [{'Danika': 0,
#   'Hannah': 2,
#   'Amy': 0,
#   'Chris': 1,
#   'Kathy': 0,
#   'Carol': 2,
#   'Alvin': 2,
#   'Will': 1,
#   'David': 0,
#   'Tex': 2,
#   'Kalos': 0,
#   'Glen': 0,
#   'Shwe': 1,
#   'Vick': 2,
#   'Margo': 0,
#   'Audrey G': 1,
#   'Eric': 0,
#   'Janice': 1,
#   'Daniel': 1,
#   'Cody': 1,
#   'Christy': 1,
#   'Steph': 2,
#   'Audrey K': 0,
#   'Christina': 2,
#   'Ricky': 2,
#   'Serena': 0,
#   'Sophia': 2},
#  {'Danika': 1,
#   'Hannah': 0,
#   'Amy': 2,
#   'Chris': 2,
#   'Kathy': 1,
#   'Carol': 0,
#   'Alvin': 0,
#   'Will': 0,
#   'David': 0,
#   'Tex': 2,
#   'Kalos': 1,
#   'Glen': 0,
#   'Shwe': 0,
#   'Vick': 1,
#   'Margo': 0,
#   'Audrey G': 1,
#   'Eric': 1,
#   'Janice': 1,
#   'Daniel': 2,
#   'Cody': 1,
#   'Christy': 2,
#   'Steph': 0,
#   'Audrey K': 2,
#   'Christina': 1,
#   'Ricky': 0,
#   'Serena': 1,
#   'Sophia': 2},
#  {'Danika': 1,
#   'Hannah': 2,
#   'Amy': 0,
#   'Chris': 2,
#   'Kathy': 0,
#   'Carol': 0,
#   'Alvin': 2,
# ...

# %%
a = [{}, {}]
a[1][1]=2
a
# Out:
# [{}, {1: 2}]
