# %%
import random
import scipy.stats as ss
import math

# %%
#Add senior council?

BOARD = ['Danika', 'Hannah', 'Amy', 'Chris',
        'Kathy', 'Carol', 'Alvin', 'Will', 
        'David', 'Tex', 'Kalos', 'Glen',
        'Shwe', 'Vick', 'Margo', 'Audrey G', 
        'Eric', 'Janice', 'Daniel', 'Cody', 
        'Christy', 'Steph', 'Audrey K', 'Christina',
        'Ricky', 'Sernea', 'Sophia']
GROUP_SIZE = 4
boardSize = len(BOARD)
EVEN_OUT_INDEX = 24
history = {}

# %%
def initialize():
    randomNums = [random.random() for _ in range(boardSize)]
    
    # converts random floats to rank ordering
    ranks = ss.rankdata(randomNums)
    
    # matches a random number 1-30 to board members
    board = zip(BOARD, ranks)
    
    # sort members by random number (1-4 is a group, 2-8...)
    board = sorted(board, key = lambda p: p[1])
    
    
    for i in range(0, boardSize, 4):
        tmp = []
        tmp += [board[i][0], board[i+1][0], board[i+2][0]]
        if i != EVEN_OUT_INDEX:
            tmp += [board[i+3][0]]
        if 'Chris' in tmp and 'Christina' in tmp or sorted(tmp) in history.values():
            print('redo')
            return('redo')
        
    for i in range(0, boardSize, 4):
        tmp = []
        tmp += [board[i][0], board[i+1][0], board[i+2][0]]
        if i != EVEN_OUT_INDEX:
            tmp += [board[i+3][0]]
        history[len(history)] = sorted(tmp)
        (print(', '.join(tmp)))
        

if __name__ == "__main__":
    for i in range(1,17):
        print("Week", i)
        while initialize() == 'redo':
            pass
# Out:
# Week 1
# Christina, David, Hannah, Eric
# Shwe, Vick, Will, Steph
# Margo, Sophia, Janice, Carol
# Glen, Sernea, Audrey K, Daniel
# Chris, Kalos, Danika, Cody
# Alvin, Audrey G, Christy, Amy
# Tex, Ricky, Kathy
# Week 2
# Kathy, Vick, Janice, Kalos
# Sernea, Margo, Steph, Daniel
# Audrey G, Cody, Ricky, Eric
# Audrey K, Chris, Glen, Alvin
# Carol, Christina, David, Amy
# Danika, Hannah, Tex, Will
# Shwe, Sophia, Christy
# Week 3
# redo
# Sophia, Will, Sernea, Hannah
# Ricky, Eric, Daniel, Amy
# Christy, Kalos, Carol, Cody
# Alvin, Audrey G, Chris, Shwe
# Margo, Danika, Glen, Audrey K
# Janice, Vick, Christina, Kathy
# David, Steph, Tex
# Week 4
# redo
# Audrey G, Eric, Kathy, Daniel
# Margo, Will, Audrey K, Cody
# Shwe, Danika, Sophia, Hannah
# Christy, Carol, Steph, Alvin
# Christina, Ricky, Kalos, Amy
# David, Vick, Glen, Janice
# Tex, Sernea, Chris
# Week 5
# redo
# Audrey K, Christy, Ricky, Chris
# David, Carol, Daniel, Alvin
# Cody, Shwe, Sophia, Kalos
# Tex, Christina, Janice, Vick
# Steph, Will, Kathy, Glen
# Audrey G, Margo, Amy, Eric
# Sernea, Danika, Hannah
# Week 6
# Christy, Ricky, Christina, Eric
# Sernea, Margo, Danika, Janice
# Glen, Sophia, Shwe, Alvin
# Will, Cody, Kalos, Kathy
# Daniel, Audrey G, Audrey K, Hannah
# Amy, Steph, Carol, David
# Chris, Vick, Tex
# Week 7
# Kathy, Alvin, Sophia, Kalos
# Eric, Chris, Steph, Hannah
# Vick, Cody, Christina, Will
# Glen, Sernea, Margo, Amy
# Danika, Audrey G, Christy, Audrey K
# Janice, Carol, Daniel, David
# Tex, Shwe, Ricky
# Week 8
# Will, Ricky, Daniel, Amy
# Eric, Alvin, Hannah, Kalos
# Christy, Shwe, Christina, Janice
# Glen, Tex, Kathy, David
# Cody, Chris, Sophia, Margo
# Vick, Sernea, Steph, Carol
# Audrey G, Danika, Audrey K
# Week 9
# Shwe, Christina, Eric, Danika
# Audrey K, Steph, Glen, Daniel
# Sernea, Amy, Chris, Ricky
# Audrey G, Cody, Christy, Will
# Kalos, Janice, Margo, Hannah
# Kathy, Sophia, Tex, Vick
# Alvin, David, Carol
# Week 10
# Kalos, Hannah, Sernea, Amy
# Ricky, Janice, Christina, Tex
# Kathy, Daniel, Alvin, Steph
# David, Sophia, Margo, Carol
# Eric, Glen, Audrey G, Audrey K
# Vick, Cody, Chris, Will
# Shwe, Danika, Christy
# Week 11
# redo
# Chris, Danika, Audrey G, Tex
# Kalos, Margo, Ricky, Vick
# Eric, Shwe, Janice, David
# Kathy, Christy, Will, Alvin
# Glen, Carol, Amy, Hannah
# Sophia, Christina, Cody, Audrey K
# Steph, Sernea, Daniel
# Week 12
# Alvin, Christina, Audrey K, David
# Steph, Eric, Kalos, Janice
# Vick, Carol, Sophia, Amy
# Hannah, Ricky, Glen, Cody
# Kathy, Tex, Shwe, Sernea
# Audrey G, Danika, Christy, Will
# Chris, Margo, Daniel
# Week 13
# redo
# Alvin, Kathy, Vick, Margo
# Amy, Shwe, Danika, Eric
# Sophia, Audrey K, Steph, Carol
# Ricky, Janice, Chris, Hannah
# Kalos, Cody, Christina, Christy
# Sernea, Tex, Will, Glen
# David, Daniel, Audrey G
# Week 14
# Kalos, Amy, Daniel, Will
# Alvin, Vick, Eric, Chris
# Kathy, Christy, Audrey K, Audrey G
# David, Margo, Hannah, Shwe
# Ricky, Steph, Christina, Tex
# Danika, Cody, Glen, Sernea
# Janice, Sophia, Carol
# Week 15
# Christina, Amy, David, Sophia
# Audrey G, Cody, Carol, Sernea
# Audrey K, Glen, Daniel, Danika
# Janice, Hannah, Alvin, Margo
# Kathy, Tex, Kalos, Christy
# Will, Ricky, Chris, Eric
# Steph, Shwe, Vick
# Week 16
# redo
# Audrey K, Shwe, Christina, Amy
# Sernea, Kalos, Vick, Will
# Sophia, Chris, Christy, Hannah
# Alvin, Margo, Danika, Daniel
# Kathy, David, Eric, Carol
# Tex, Ricky, Audrey G, Janice
# Cody, Steph, Glen

# %%
history
# Out:
# {0: ['Alvin', 'Chris', 'Danika', 'Shwe'],
#  1: ['Carol', 'Glen', 'Sernea', 'Will'],
#  2: ['Christina', 'Cody', 'Kalos', 'Steph'],
#  3: ['Amy', 'Christy', 'Margo', 'Tex'],
#  4: ['Daniel', 'David', 'Hannah', 'Ricky'],
#  5: ['Audrey G', 'Audrey K', 'Eric', 'Vick'],
#  6: ['Janice', 'Kathy', 'Sophia'],
#  7: ['Chris', 'Danika', 'David', 'Ricky'],
#  8: ['Christy', 'Daniel', 'Hannah', 'Shwe'],
#  9: ['Audrey G', 'Audrey K', 'Cody', 'Janice'],
#  10: ['Margo', 'Steph', 'Vick', 'Will'],
#  11: ['Amy', 'Eric', 'Kalos', 'Sophia'],
#  12: ['Alvin', 'Christina', 'Glen', 'Sernea'],
#  13: ['Carol', 'Kathy', 'Tex'],
#  14: ['Alvin', 'Eric', 'Kalos', 'Margo'],
#  15: ['Amy', 'Cody', 'Danika', 'Steph'],
#  16: ['Audrey K', 'Glen', 'Shwe', 'Will'],
#  17: ['Audrey G', 'Christina', 'David', 'Ricky'],
#  18: ['Carol', 'Hannah', 'Kathy', 'Vick'],
#  19: ['Christy', 'Daniel', 'Janice', 'Tex'],
#  20: ['Chris', 'Sernea', 'Sophia'],
#  21: ['Audrey K', 'Cody', 'Kathy', 'Will'],
#  22: ['Audrey G', 'Eric', 'Janice', 'Margo'],
#  23: ['Daniel', 'Danika', 'Kalos', 'Shwe'],
#  24: ['Alvin', 'Chris', 'Hannah', 'Sernea'],
#  25: ['Carol', 'Christina', 'Ricky', 'Tex'],
#  26: ['Amy', 'Christy', 'Glen', 'Steph'],
#  27: ['David', 'Sophia', 'Vick'],
#  28: ['Chris', 'David', 'Shwe', 'Vick'],
#  29: ['Hannah', 'Margo', 'Ricky', 'Sophia'],
#  30: ['Audrey K', 'Eric', 'Sernea', 'Tex'],
#  31: ['Christy', 'Daniel', 'Glen', 'Will'],
#  32: ['Amy', 'Danika', 'Kathy', 'Steph'],
#  33: ['Carol', 'Christina', 'Cody', 'Janice'],
#  34: ['Alvin', 'Audrey G', 'Kalos'],
#  35: ['Daniel', 'Danika', 'Sernea', 'Will'],
#  36: ['Cody', 'Glen', 'Kathy', 'Steph'],
#  37: ['Audrey G', 'Carol', 'Christina', 'Hannah'],
#  38: ['Audrey K', 'Christy', 'Shwe', 'Sophia'],
#  39: ['Alvin', 'Chris', 'Kalos', 'Margo'],
#  40: ['Amy', 'David', 'Tex', 'Vick'],
#  41: ['Eric', 'Janice', 'Ricky'],
#  42: ['Audrey G', 'David', 'Eric', 'Sophia'],
#  43: ['Janice', 'Kathy', 'Vick', 'Will'],
#  44: ['Chris', 'Hannah', 'Margo', 'Sernea'],
#  45: ['Alvin', 'Carol', 'Glen', 'Kalos'],
#  46: ['Christina', 'Daniel', 'Steph', 'Tex'],
#  47: ['Amy', 'Audrey K', 'Christy', 'Danika'],
#  48: ['Cody', 'Ricky', 'Shwe'],
#  49: ['Amy', 'Chris', 'David', 'Shwe'],
#  50: ['Carol', 'Daniel', 'Danika', 'Kathy'],
#  51: ['Audrey G', 'Eric', 'Glen', 'Janice'],
#  52: ['Alvin', 'Christy', 'Margo', 'Sernea'],
#  53: ['Cody', 'Kalos', 'Sophia', 'Tex'],
#  54: ['Christina', 'Hannah', 'Ricky', 'Steph'],
#  55: ['Audrey K', 'Vick', 'Will'],
#  56: ['Carol', 'David', 'Ricky', 'Steph'],
#  57: ['Alvin', 'Audrey G', 'Janice', 'Sophia'],
#  58: ['Christina', 'Christy', 'Margo', 'Shwe'],
#  59: ['Amy', 'Tex', 'Vick', 'Will'],
#  60: ['Chris', 'Eric', 'Glen', 'Hannah'],
#  61: ['Audrey K', 'Daniel', 'Kalos', 'Kathy'],
#  62: ['Cody', 'Danika', 'Sernea'],
#  63: ['Audrey K', 'Christina', 'Hannah', 'Janice'],
#  64: ['Amy', 'Steph', 'Tex', 'Will'],
#  65: ['Carol', 'Daniel', 'Eric', 'Shwe'],
#  66: ['Ricky', 'Sernea', 'Sophia', 'Vick'],
#  67: ['Alvin', 'Christy', 'Glen', 'Kathy'],
#  68: ['Audrey G', 'Chris', 'Danika', 'Kalos'],
#  69: ['Cody', 'David', 'Margo'],
#  70: ['Amy', 'Carol', 'Sernea', 'Vick'],
#  71: ['Audrey G', 'Christina', 'Eric', 'Sophia'],
#  72: ['Audrey K', 'Chris', 'David', 'Tex'],
#  73: ['Christy', 'Cody', 'Daniel', 'Danika'],
#  74: ['Alvin', 'Glen', 'Hannah', 'Kathy'],
#  75: ['Janice', 'Kalos', 'Margo', 'Shwe'],
#  76: ['Ricky', 'Steph', 'Will'],
#  77: ['Amy', 'Glen', 'Hannah', 'Tex'],
#  78: ['Audrey K', 'Chris', 'Eric', 'Sernea'],
#  79: ['Cody', 'Janice', 'Kathy', 'Ricky'],
#  80: ['Christy', 'Kalos', 'Margo', 'Vick'],
#  81: ['Alvin', 'Christina', 'Danika', 'Shwe'],
#  82: ['Audrey G', 'Carol', 'Daniel', 'Sophia'],
#  83: ['David', 'Steph', 'Will'],
#  84: ['Audrey G', 'Cody', 'Hannah', 'Ricky'],
#  85: ['Janice', 'Sernea', 'Shwe', 'Sophia'],
#  86: ['Amy', 'Carol', 'Chris', 'David'],
#  87: ['Christina', 'Christy', 'Kathy', 'Steph'],
#  88: ['Kalos', 'Margo', 'Tex', 'Will'],
#  89: ['Alvin', 'Daniel', 'Danika', 'Vick'],
#  90: ['Audrey K', 'Eric', 'Glen'],
#  91: ['Audrey G', 'Danika', 'Glen', 'Kathy'],
#  92: ['Christina', 'David', 'Eric', 'Margo'],
#  93: ['Audrey K', 'Chris', 'Cody', 'Kalos'],
#  94: ['Daniel', 'Hannah', 'Steph', 'Will'],
#  95: ['Christy', 'Shwe', 'Sophia', 'Vick'],
#  96: ['Alvin', 'Amy', 'Janice', 'Ricky'],
#  97: ['Carol', 'Sernea', 'Tex'],
#  98: ['Chris', 'Daniel', 'Eric', 'Kalos'],
#  99: ['Christina', 'Danika', 'David', 'Kathy'],
#  100: ['Amy', 'Audrey K', 'Carol', 'Shwe'],
#  101: ['Christy', 'Janice', 'Ricky', 'Will'],
#  102: ['Audrey G', 'Glen', 'Margo', 'Steph'],
#  103: ['Cody', 'Sernea', 'Sophia', 'Vick'],
#  104: ['Alvin', 'Hannah', 'Tex'],
#  105: ['Carol', 'Sernea', 'Tex', 'Vick'],
#  106: ['Hannah', 'Kalos', 'Shwe', 'Steph'],
#  107: ['Audrey K', 'David', 'Janice', 'Will'],
#  108: ['Amy', 'Danika', 'Glen', 'Ricky'],
#  109: ['Alvin', 'Chris', 'Cody', 'Sophia'],
#  110: ['Christina', 'Daniel', 'Eric', 'Kathy'],
#  111: ['Audrey G', 'Christy', 'Margo'],
#  112: ['Audrey G', 'Daniel', 'David', 'Vick'],
#  113: ['Carol', 'Margo', 'Ricky', 'Sernea'],
#  114: ['Christina', 'Sophia', 'Steph', 'Will'],
#  115: ['Amy', 'Danika', 'Glen', 'Kathy'],
#  116: ['Alvin', 'Chris', 'Janice', 'Tex'],
#  117: ['Christy', 'Cody', 'Kalos', 'Shwe'],
#  118: ['Audrey K', 'Eric', 'Hannah'],
#  119: ['Audrey G', 'Cody', 'Hannah', 'Steph'],
#  120: ['Amy', 'Christina', 'Glen', 'Will'],
#  121: ['Alvin', 'Daniel', 'Eric', 'Ricky'],
#  122: ['Christy', 'Danika', 'Margo', 'Sophia'],
#  123: ['Carol', 'Janice', 'Kalos', 'Shwe'],
#  124: ['Audrey K', 'Kathy', 'Sernea', 'Tex'],
#  125: ['Chris', 'David', 'Vick'],
#  126: ['Amy', 'Audrey K', 'Kalos', 'Tex'],
#  127: ['Christy', 'Eric', 'Sernea', 'Steph'],
#  128: ['Christina', 'Cody', 'Danika', 'Vick'],
#  129: ['Alvin', 'Glen', 'Hannah', 'Will'],
#  130: ['Daniel', 'Janice', 'Margo', 'Ricky'],
#  131: ['Audrey G', 'David', 'Shwe', 'Sophia'],
#  132: ['Carol', 'Chris', 'Kathy'],
#  133: ['Alvin', 'Christina', 'Kathy', 'Tex'],
#  134: ['Danika', 'Margo', 'Sernea', 'Steph'],
#  135: ['Christy', 'David', 'Glen', 'Ricky'],
#  136: ['Audrey G', 'Carol', 'Kalos', 'Shwe'],
#  137: ['Amy', 'Chris', 'Cody', 'Vick'],
#  138: ['Audrey K', 'Hannah', 'Janice', 'Will'],
#  139: ['Daniel', 'Eric', 'Sophia'],
#  140: ['Carol', 'Glen', 'Shwe', 'Sophia'],
#  141: ['David', 'Janice', 'Steph', 'Tex'],
#  142: ['Audrey G', 'Christina', 'Eric', 'Margo'],
#  143: ['Chris', 'Daniel', 'Ricky', 'Sernea'],
#  144: ['Alvin', 'Audrey K', 'Danika', 'Vick'],
#  145: ['Amy', 'Cody', 'Kathy', 'Will'],
#  146: ['Christy', 'Hannah', 'Kalos'],
#  147: ['Alvin', 'Kalos', 'Sernea', 'Shwe'],
#  148: ['Audrey K', 'Christy', 'Eric', 'Glen'],
#  149: ['Carol', 'David', 'Janice', 'Sophia'],
#  150: ['Hannah', 'Ricky', 'Tex', 'Will'],
#  151: ['Christina', 'Cody', 'Danika', 'Margo'],
#  152: ['Amy', 'Audrey G', 'Daniel', 'Steph'],
#  153: ['Chris', 'Kathy', 'Vick'],
#  154: ['Amy', 'Christina', 'Hannah', 'Sophia'],
#  155: ['Audrey G', 'Cody', 'Tex', 'Will'],
#  156: ['Carol', 'Eric', 'Glen', 'Vick'],
#  157: ['Chris', 'Daniel', 'David', 'Shwe'],
#  158: ['Kalos', 'Kathy', 'Margo', 'Ricky'],
#  159: ['Alvin', 'Christy', 'Janice', 'Steph'],
#  160: ['Audrey K', 'Danika', 'Sernea'],
#  161: ['Audrey G', 'Christina', 'Daniel', 'Shwe'],
#  162: ['Christy', 'Hannah', 'Tex', 'Vick'],
#  163: ['Chris', 'Glen', 'Janice', 'Sophia'],
#  164: ['Alvin', 'Eric', 'Ricky', 'Will'],
#  165: ['Carol', 'Cody', 'Danika', 'Sernea'],
#  166: ['Amy', 'Audrey K', 'Kalos', 'Steph'],
#  167: ['David', 'Kathy', 'Margo'],
#  168: ['Amy', 'Shwe', 'Sophia', 'Will'],
#  169: ['Audrey K', 'Chris', 'Daniel', 'Ricky'],
#  170: ['Alvin', 'Carol', 'David', 'Margo'],
#  171: ['Audrey G', 'Christina', 'Glen', 'Steph'],
#  172: ['Danika', 'Eric', 'Janice', 'Vick'],
#  173: ['Hannah', 'Kathy', 'Sernea', 'Tex'],
#  174: ['Christy', 'Cody', 'Kalos'],
#  175: ['Audrey G', 'Chris', 'Glen', 'Sophia'],
#  176: ['Christy', 'Daniel', 'David', 'Eric'],
#  177: ['Hannah', 'Janice', 'Ricky', 'Steph'],
#  178: ['Alvin', 'Amy', 'Carol', 'Sernea'],
#  179: ['Danika', 'Margo', 'Vick', 'Will'],
#  180: ['Audrey K', 'Kalos', 'Kathy', 'Shwe'],
#  181: ['Christina', 'Cody', 'Tex'],
#  182: ['Audrey K', 'Hannah', 'Sophia', 'Steph'],
#  183: ['Christy', 'Danika', 'David', 'Janice'],
#  184: ['Chris', 'Cody', 'Glen', 'Ricky'],
#  185: ['Christina', 'Daniel', 'Kalos', 'Shwe'],
#  186: ['Carol', 'Kathy', 'Tex', 'Vick'],
#  187: ['Alvin', 'Audrey G', 'Eric', 'Will'],
#  188: ['Amy', 'Margo', 'Sernea'],
#  189: ['Amy', 'Audrey G', 'Christina', 'David'],
#  190: ['Kalos', 'Sernea', 'Sophia', 'Steph'],
#  191: ['Chris', 'Hannah', 'Tex', 'Will'],
#  192: ['Alvin', 'Audrey K', 'Carol', 'Shwe'],
#  193: ['Christy', 'Cody', 'Danika', 'Ricky'],
#  194: ['Daniel', 'Eric', 'Janice', 'Kathy'],
#  195: ['Glen', 'Margo', 'Vick'],
#  196: ['Audrey G', 'Danika', 'Margo', 'Tex'],
#  197: ['Amy', 'Chris', 'Kathy', 'Vick'],
#  198: ['Alvin', 'Cody', 'Kalos', 'Sophia'],
#  199: ['Christina', 'Daniel', 'Eric', 'Hannah'],
#  200: ['Christy', 'David', 'Shwe', 'Will'],
#  201: ['Audrey K', 'Carol', 'Glen', 'Steph'],
#  202: ['Janice', 'Ricky', 'Sernea'],
#  203: ['Audrey G', 'Danika', 'Janice', 'Steph'],
#  204: ['Alvin', 'Christy', 'Kathy', 'Sernea'],
#  205: ['David', 'Eric', 'Kalos', 'Shwe'],
#  206: ['Amy', 'Audrey K', 'Sophia', 'Will'],
#  207: ['Chris', 'Glen', 'Hannah', 'Vick'],
#  208: ['Cody', 'Daniel', 'Margo', 'Tex'],
#  209: ['Carol', 'Christina', 'Ricky']}
